# %% [markdown]
# # Pandas intro (short)

# %% [markdown]
# ## Basics

# %%
# !pip install pandas
# Out:
# ...
# WARNING: Error parsing requirements for absl-py: [Errno 2] No such file or directory: 'c:\\users\\gery\\anaconda3\\lib\\site-packages\\absl_py-0.12.0.dist-info\\METADATA'
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/gergobogacsovics/ML_in_practice/main/data/1/healthcare-dataset-stroke-data-clean.csv")

# %%
df.head()
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0  67.0             0              1             1             228.69
# 1  61.0             0              0             1             202.21
# 2  80.0             0              1             1             105.92
# 3  49.0             0              0             1             171.23
# 4  79.0             1              0             1             174.12
#
#          bmi  stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0  36.600000       1            1             0                       0
# 1  28.893237       1            0             0                       0
# 2  32.500000       1            1             0                       0
# 3  34.400000       1            0             0                       0
# 4  24.000000       1            0             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# ...

# %%
df.head(2)
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0  67.0             0              1             1             228.69
# 1  61.0             0              0             1             202.21
#
#          bmi  stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0  36.600000       1            1             0                       0
# 1  28.893237       1            0             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# 0                  1                        0                   0
# 1                  0                        1                   0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
# 1                               0                            1
#
#    smoking_status_smokes  residence_type_Urban
# 0                      0                     1
# ...

# %%
df.tail()
# Out:
#        age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 5105  80.0             1              0             1              83.75
# 5106  81.0             0              0             1             125.20
# 5107  35.0             0              0             1              82.99
# 5108  51.0             0              0             1             166.29
# 5109  44.0             0              0             1              85.28
#
#             bmi  stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 5105  28.893237       0            0             0                       0
# 5106  40.000000       0            0             0                       0
# 5107  30.600000       0            0             0                       0
# 5108  25.600000       0            1             0                       0
# 5109  26.200000       0            0             0                       0
#
#       work_type_Private  work_type_Self-employed  work_type_children  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             5110 non-null   float64
#  1   hypertension                    5110 non-null   int64
#  2   heart_disease                   5110 non-null   int64
#  3   ever_married                    5110 non-null   int64
#  4   avg_glucose_level               5110 non-null   float64
#  5   bmi                             5110 non-null   float64
#  6   stroke                          5110 non-null   int64
#  7   gender_Male                     5110 non-null   int64
#  8   gender_Other                    5110 non-null   int64
#  9   work_type_Never_worked          5110 non-null   int64
#  10  work_type_Private               5110 non-null   int64
#  11  work_type_Self-employed         5110 non-null   int64
# ...

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  ever_married  \
# count  5110.000000   5110.000000    5110.000000   5110.000000
# mean     43.226614      0.097456       0.054012      0.656164
# std      22.612647      0.296607       0.226063      0.475034
# min       0.080000      0.000000       0.000000      0.000000
# 25%      25.000000      0.000000       0.000000      0.000000
# 50%      45.000000      0.000000       0.000000      1.000000
# 75%      61.000000      0.000000       0.000000      1.000000
# max      82.000000      1.000000       1.000000      1.000000
#
#        avg_glucose_level          bmi       stroke  gender_Male  gender_Other  \
# count        5110.000000  5110.000000  5110.000000  5110.000000   5110.000000
# mean          106.147677    28.893237     0.048728     0.413894      0.000196
# std            45.283560     7.698018     0.215320     0.492578      0.013989
# min            55.120000    10.300000     0.000000     0.000000      0.000000
# ...

# %%
df.to_numpy()
# Out:
# array([[67.,  0.,  1., ...,  0.,  0.,  1.],
#        [61.,  0.,  0., ...,  1.,  0.,  0.],
#        [80.,  0.,  1., ...,  1.,  0.,  0.],
#        ...,
#        [35.,  0.,  0., ...,  1.,  0.,  0.],
#        [51.,  0.,  0., ...,  0.,  0.,  0.],
#        [44.,  0.,  0., ...,  0.,  0.,  1.]])

# %% [markdown]
# ## Extracting information

# %%
df["age"].head()
# Out:
# 0    67.0
# 1    61.0
# 2    80.0
# 3    49.0
# 4    79.0
# Name: age, dtype: float64

# %%
df[0:5]
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0  67.0             0              1             1             228.69
# 1  61.0             0              0             1             202.21
# 2  80.0             0              1             1             105.92
# 3  49.0             0              0             1             171.23
# 4  79.0             1              0             1             174.12
#
#          bmi  stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0  36.600000       1            1             0                       0
# 1  28.893237       1            0             0                       0
# 2  32.500000       1            1             0                       0
# 3  34.400000       1            0             0                       0
# 4  24.000000       1            0             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# ...

# %%
df.loc[:5, ["age"]]
# Out:
#     age
# 0  67.0
# 1  61.0
# 2  80.0
# 3  49.0
# 4  79.0
# 5  81.0

# %%
type(df.loc[:5, ["age"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.loc[:5, "age"])
# Out:
# pandas.core.series.Series

# %%
df.iloc[:5]
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0  67.0             0              1             1             228.69
# 1  61.0             0              0             1             202.21
# 2  80.0             0              1             1             105.92
# 3  49.0             0              0             1             171.23
# 4  79.0             1              0             1             174.12
#
#          bmi  stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0  36.600000       1            1             0                       0
# 1  28.893237       1            0             0                       0
# 2  32.500000       1            1             0                       0
# 3  34.400000       1            0             0                       0
# 4  24.000000       1            0             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# ...

# %%
df.iloc[4]
# Out:
# age                                79.00
# hypertension                        1.00
# heart_disease                       0.00
# ever_married                        1.00
# avg_glucose_level                 174.12
# bmi                                24.00
# stroke                              1.00
# gender_Male                         0.00
# gender_Other                        0.00
# work_type_Never_worked              0.00
# work_type_Private                   0.00
# work_type_Self-employed             1.00
# work_type_children                  0.00
# smoking_status_formerly smoked      0.00
# smoking_status_never smoked         1.00
# smoking_status_smokes               0.00
# residence_type_Urban                0.00
# Name: 4, dtype: float64

# %%
type(df.iloc[4])
# Out:
# pandas.core.series.Series

# %%
df.iloc[:3, -2:]
# Out:
#    smoking_status_smokes  residence_type_Urban
# 0                      0                     1
# 1                      0                     0
# 2                      0                     0

# %%
df[df["stroke"] == 1]
# Out:
#       age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0    67.0             0              1             1             228.69
# 1    61.0             0              0             1             202.21
# 2    80.0             0              1             1             105.92
# 3    49.0             0              0             1             171.23
# 4    79.0             1              0             1             174.12
# ..    ...           ...            ...           ...                ...
# 244  57.0             0              0             1              84.96
# 245  14.0             0              0             0              57.93
# 246  75.0             0              0             1              78.80
# 247  71.0             1              0             1              87.80
# 248  78.0             0              0             1              78.81
#
#            bmi  stroke  gender_Male  gender_Other  work_type_Never_worked  \
# ...

# %%
df["stroke"] == 1
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 5105    False
# 5106    False
# 5107    False
# 5108    False
# 5109    False
# Name: stroke, Length: 5110, dtype: bool

# %%
df.head(1)
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level   bmi  \
# 0  67.0             0              1             1             228.69  36.6
#
#    stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0       1            1             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# 0                  1                        0                   0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
#
#    smoking_status_smokes  residence_type_Urban
# 0                      0                     1

# %% [markdown]
# ## Setting values

# %%
df.at[0, "stroke"]
# Out:
# 1

# %%
df.at[0, "stroke"] = 0

# %%
df.head(1)
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level   bmi  \
# 0  67.0             0              1             1             228.69  36.6
#
#    stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0       0            1             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# 0                  1                        0                   0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
#
#    smoking_status_smokes  residence_type_Urban
# 0                      0                     1

# %%
df.iat[0, 4] = 1

# %%
df.head(1)
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level   bmi  \
# 0  67.0             0              1             1                1.0  36.6
#
#    stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0       0            1             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# 0                  1                        0                   0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
#
#    smoking_status_smokes  residence_type_Urban
# 0                      0                     1

# %% [markdown]
# ### Beware of referencing a dataframe!

# %%
df2 = df

# %%
df2.iat[0, 4] = 0

# %%
df2.head(1)
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level   bmi  \
# 0  67.0             0              1             1                0.0  36.6
#
#    stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0       0            1             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# 0                  1                        0                   0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
#
#    smoking_status_smokes  residence_type_Urban
# 0                      0                     1

# %%
df.head(1)
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level   bmi  \
# 0  67.0             0              1             1                0.0  36.6
#
#    stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0       0            1             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# 0                  1                        0                   0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
#
#    smoking_status_smokes  residence_type_Urban
# 0                      0                     1

# %%
df.iat[0, 4] = 1

# %%
df2.head(1)
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level   bmi  \
# 0  67.0             0              1             1                1.0  36.6
#
#    stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0       0            1             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# 0                  1                        0                   0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
#
#    smoking_status_smokes  residence_type_Urban
# 0                      0                     1

# %%
df.head(1)
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level   bmi  \
# 0  67.0             0              1             1                1.0  36.6
#
#    stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0       0            1             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# 0                  1                        0                   0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
#
#    smoking_status_smokes  residence_type_Urban
# 0                      0                     1

# %% [markdown]
# ### Use the .copy() function to solve this problem!

# %%
df2 = df.copy()

# %%
df2.iat[0, 4] = 0

# %%
df2.head(1)
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level   bmi  \
# 0  67.0             0              1             1                0.0  36.6
#
#    stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0       0            1             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# 0                  1                        0                   0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
#
#    smoking_status_smokes  residence_type_Urban
# 0                      0                     1

# %%
df.head(1)
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level   bmi  \
# 0  67.0             0              1             1                1.0  36.6
#
#    stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0       0            1             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# 0                  1                        0                   0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
#
#    smoking_status_smokes  residence_type_Urban
# 0                      0                     1

# %%
df.iat[0, 4] = 2

# %%
df.head(1)
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level   bmi  \
# 0  67.0             0              1             1                2.0  36.6
#
#    stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0       0            1             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# 0                  1                        0                   0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
#
#    smoking_status_smokes  residence_type_Urban
# 0                      0                     1

# %%
df2.head(1)
# Out:
#     age  hypertension  heart_disease  ever_married  avg_glucose_level   bmi  \
# 0  67.0             0              1             1                0.0  36.6
#
#    stroke  gender_Male  gender_Other  work_type_Never_worked  \
# 0       0            1             0                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# 0                  1                        0                   0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
#
#    smoking_status_smokes  residence_type_Urban
# 0                      0                     1

# %%
df.iat[0, 4] = 1

# %% [markdown]
# ## Statistics

# %%
df.mean()
# Out:
# age                                43.226614
# hypertension                        0.097456
# heart_disease                       0.054012
# ever_married                        0.656164
# avg_glucose_level                 106.103119
# bmi                                28.893237
# stroke                              0.048532
# gender_Male                         0.413894
# gender_Other                        0.000196
# work_type_Never_worked              0.004305
# work_type_Private                   0.572407
# work_type_Self-employed             0.160274
# work_type_children                  0.134442
# smoking_status_formerly smoked      0.173190
# smoking_status_never smoked         0.370254
# smoking_status_smokes               0.154403
# residence_type_Urban                0.508023
# dtype: float64

# %%
# df.mean(1) # other axis

# %%
df["stroke"].value_counts()
# Out:
# 0    4862
# 1     248
# Name: stroke, dtype: int64
